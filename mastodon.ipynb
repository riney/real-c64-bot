# %%
from mastodon import Mastodon

# %%
mastodon = Mastodon(client_id = 'mastodon_test.secret')

# %%
mastodon.retrieve_mastodon_version()
# Out:
# '4.0.0rc3'

# %%
toots = mastodon.timeline_hashtag('caturday', limit=5)

# %%
toots
# Out:
# [{'id': 109334101842425660,
#   'created_at': datetime.datetime(2022, 11, 13, 2, 19, 33, tzinfo=tzutc()),
#   'in_reply_to_id': None,
#   'in_reply_to_account_id': None,
#   'sensitive': False,
#   'spoiler_text': '',
#   'visibility': 'public',
#   'language': 'en',
#   'uri': 'https://weburbanists.com/users/IcooIey/statuses/109334100294069192',
#   'url': 'https://weburbanists.com/@IcooIey/109334100294069192',
#   'replies_count': 0,
#   'reblogs_count': 0,
#   'favourites_count': 1,
#   'edited_at': None,
#   'content': '<p>Is it still <a href="https://weburbanists.com/tags/caturday" class="mention hashtag" rel="nofollow noopener noreferrer" target="_blank">#<span>caturday</span></a>? Fisher helped clean up the garden today (he polished off the rest of the catnip—it’s the weekend.)</p>',
#   'reblog': None,
#   'account': {'id': 109303671830178241,
#    'username': 'IcooIey',
#    'acct': 'IcooIey@weburbanists.com',
#    'display_name': 'IcooIey',
#    'locked': False,
# ...
